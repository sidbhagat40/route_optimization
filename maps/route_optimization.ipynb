# %% [markdown]
# <a href="https://colab.research.google.com/github/sidbhagat40/route_optimization/blob/main/route_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import osmnx as ox
import folium

# %%
# Get graph
graph = ox.graph_from_address("Jodhpur Railway Station, Rajasthan", dist=1000)

# Convert graph to GeoDataFrame
nodes, edges = ox.graph_to_gdfs(graph)

# Create Folium map centered on graph
x, y = edges.unary_union.centroid.xy
m = folium.Map(location=[y[0], x[0]], zoom_start=15)

# Add each road segment to the map
for _, row in edges.iterrows():
    folium.PolyLine(
        locations=[(lat, lon) for lon, lat in row.geometry.coords],
        color='blue',
        weight=2
    ).add_to(m)

m
# Out:
# <ipython-input-20-b4b62116807c>:8: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   x, y = edges.unary_union.centroid.xy
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nodes, edges = osmnx.graph_to_gdfs(graph)

edges
# Out:
#                                   osmid      highway  oneway   ref reversed  \
# u           v           key
# 354586313   8503427862  0      31676039      primary    True  NH25    False
#             2688529178  0     915442675     tertiary    True   NaN    False
# 354586318   8509825598  0      31676039      primary    True  NH25    False
#             2688566081  0     190271468  residential    True   NaN    False
# 354587332   2567581159  0      31676081      primary    True  NH25    False
# ...                                 ...          ...     ...   ...      ...
# 11443285573 11443285574 0    1233272595  residential   False   NaN    False
#             8527549461  0     918175542  residential   False   NaN     True
# 11443285574 8527549457  0     369858796  residential   False   NaN    False
#             11443285573 0    1233272595  residential   False   NaN     True
#             8527549461  0     369858796  residential   False   NaN     True
#
# ...
